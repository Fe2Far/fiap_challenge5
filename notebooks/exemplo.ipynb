# %% [markdown]
# # Notebook de Exemplo
#
# Este é um notebook básico para o projeto FIAP Challenge 5.
#
# Use este notebook como base para seus experimentos e análises.

# %%
print('Olá, mundo!')
print('Bem-vindo ao Jupyter Notebook!')

# Aqui você pode adicionar seu código Python
